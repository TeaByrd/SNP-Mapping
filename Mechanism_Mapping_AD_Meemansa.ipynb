# %%
import pandas as pd

# %%
#loading neurommsig_mechanisms
mechanisms=pd.read_excel('../Downloads/AD.xlsx')
MechanismToGene=mechanisms.to_dict("list")

# %% [markdown]
# mechanisms

# %%
mechanisms=mechanisms.drop(["NeuroMMSig identifier","PMIDs","Imaging Features (Anandhi)","In silico","Animal models (Shweta)","Epidemiology (?)"],axis=1)

# %%
mechanisms #warten auf Meemansas Anweisung welche Gene sie will
# Out:
#                Subgraph Name  Genes SNPs from Literature (Aybuge)  \
# 0     Amyloidogenic subgraph    APP           rs459543, rs1800557
# 1                        NaN  APLP1                           NaN
# 2                        NaN  APLP2                    rs11822318
# 3                        NaN  APBA3                           NaN
# 4                        NaN  APBA1                           NaN
# ...                      ...    ...                           ...
# 1192                     NaN   RFC1                           NaN
# 1193                     NaN    MTR                           NaN
# 1194                     NaN  SIN3A                           NaN
# 1195                     NaN    NaN                           NaN
# 1196           DKK1 subgraph   DKK1                           NaN
#
#                  Genome wide associated SNPs (Mufassra)  \
# 0                                                   NaN
# 1                                                   NaN
# ...
